# %%
# Out:
# Requirement already satisfied: keras in /Users/user/opt/anaconda3/lib/python3.9/site-packages (2.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataset_path = "/Users/user/Documents/2022-2023/Practice/Isolation/DL-MATH-II/Project_II/archive"

labels = os.listdir(dataset_path)
print(labels)

for label in labels:
    print(os.listdir(os.path.join(dataset_path, label)))    #listing number of folders and sub-folders in dataset
# Out:
# ['.DS_Store', 'test', 'train']
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/rr/w2vd3_rn7j5d43t_krxm9hj00000gn/T/ipykernel_12765/2724579278.py in <module>
#       5
#       6 for label in labels:
# ----> 7     print(os.listdir(os.path.join(dataset_path, label)))    #listing number of folders and sub-folders in dataset
#
# NotADirectoryError: [Errno 20] Not a directory: '/Users/user/Documents/2022-2023/Practice/Isolation/DL-MATH-II/Project_II/archive/.DS_Store'

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
train_dir = "/content/archive/train"
test_dir = "../content/archive/test"

# %%
#preparing training data
img_size=48
train_datagen = ImageDataGenerator(      width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         validation_split = 0.2
                                        )

train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rr/w2vd3_rn7j5d43t_krxm9hj00000gn/T/ipykernel_12765/3092010213.py in <module>
#       1 #preparing training data
#       2 img_size=48
# ----> 3 train_datagen = ImageDataGenerator(      width_shift_range = 0.1,
#       4                                          height_shift_range = 0.1,
#       5                                          horizontal_flip = True,
#
# NameError: name 'ImageDataGenerator' is not defined
